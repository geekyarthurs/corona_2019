# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Setting SNS
sns.set()

# %%
df = pd.read_csv("covid_19_data.csv")

# %%
df.head(3)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0

# %%
df.set_index('Last Update', inplace=True)

# %%
df.index
# Out:
# Index(['1/22/2020 17:00', '1/22/2020 17:00', '1/22/2020 17:00',
#        '1/22/2020 17:00', '1/22/2020 17:00', '1/22/2020 17:00',
#        '1/22/2020 17:00', '1/22/2020 17:00', '1/22/2020 17:00',
#        '1/22/2020 17:00',
#        ...
#        '2020-03-05T23:33:03', '2020-03-06T20:13:14', '2020-03-03T15:33:02',
#        '2020-03-06T15:43:02', '2020-02-29T02:03:10', '2020-03-06T04:33:03',
#        '2020-02-24T23:33:02', '2020-03-07T19:53:02', '2020-02-24T23:33:02',
#        '2020-02-24T23:33:02'],
#       dtype='object', name='Last Update', length=4513)

# %%
df = df.reindex(pd.to_datetime(df.index))

# %%
df
# Out:
#                       SNo ObservationDate  \
# Last Update
# 2020-01-22 17:00:00     1      01/22/2020
# 2020-01-22 17:00:00     2      01/22/2020
# 2020-01-22 17:00:00     3      01/22/2020
# 2020-01-22 17:00:00     4      01/22/2020
# 2020-01-22 17:00:00     5      01/22/2020
# ...                   ...             ...
# 2020-03-06 04:33:03  4509      03/09/2020
# 2020-02-24 23:33:02  4510      03/09/2020
# 2020-03-07 19:53:02  4511      03/09/2020
# 2020-02-24 23:33:02  4512      03/09/2020
# 2020-02-24 23:33:02  4513      03/09/2020
#
#                                            Province/State  Country/Region  \
# Last Update
# 2020-01-22 17:00:00                                 Anhui  Mainland China
# 2020-01-22 17:00:00                               Beijing  Mainland China
# 2020-01-22 17:00:00                             Chongqing  Mainland China
# 2020-01-22 17:00:00                                Fujian  Mainland China
# ...

# %%
sample = df.resample('5D').sum()

# %%
sample
# Out:
#                  SNo  Confirmed   Deaths  Recovered
# Last Update
# 2020-01-22     23436     5705.0    159.0      185.0
# 2020-01-27    154884    33056.0    730.0      676.0
# 2020-02-01    644775   100607.0   2104.0     3354.0
# 2020-02-06    445329   185383.0   4078.0    13385.0
# 2020-02-11    887628   286555.0   6818.0    33968.0
# 2020-02-16    478362   372360.0  10008.0    72012.0
# 2020-02-21   1044914   393470.0  12504.0   118614.0
# 2020-02-26   1433411   422582.0  14393.0   182702.0
# 2020-03-02   2923160   482912.0  16346.0   257161.0
# 2020-03-07   2149942   323451.0  11307.0   178528.0

# %%
sns.lineplot(x='Last Update',y='Deaths',data=sample.reset_index(),label="Deaths")
sns.lineplot(x='Last Update',y='Confirmed',data=sample.reset_index(),label="Confirmed Deaths")

plt.xticks(rotation=45)
# Out:
# (array([737446., 737456., 737463., 737470., 737477., 737485., 737492.]),
#  <a list of 7 Text xticklabel objects>)

# %%
sns.relplot(x='Last Update',y='Confirmed',data=df.reset_index(),col="Country/Region",label="Confirmed Deaths",kind='line')
plt.xticks(rotation=45)
# Out:
# (array([737446., 737456., 737463., 737470., 737477., 737485., 737492.]),
#  <a list of 7 Text xticklabel objects>)
# Error in callback <function flush_figures at 0x7ff245e918c0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.anaconda3/envs/machine_learning/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/.anaconda3/envs/machine_learning/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ...

# %%
df[df['Country/Region']== "Mainland China"]["Province/State"].value_counts()
# Out:
# Guangxi           48
# Sichuan           48
# Xinjiang          48
# Shanghai          48
# Shanxi            48
# Tianjin           48
# Shandong          48
# Jiangxi           48
# Hubei             48
# Guangdong         48
# Liaoning          48
# Anhui             48
# Ningxia           48
# Yunnan            48
# Inner Mongolia    48
# Henan             48
# Hunan             48
# Hebei             48
# Fujian            48
# Chongqing         48
# Guizhou           48
# Hainan            48
# Zhejiang          48
# Heilongjiang      48
# Jilin             48
# Shaanxi           48
# Beijing           48
# Qinghai           48
# Gansu             48
# Jiangsu           48
# Tibet             42
# Name: Province/State, dtype: int64
